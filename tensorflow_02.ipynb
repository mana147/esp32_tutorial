# %% [markdown]
# <a href="https://colab.research.google.com/github/mana147/ESP32_RTOS_IDF/blob/master/tensorflow_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Keras
